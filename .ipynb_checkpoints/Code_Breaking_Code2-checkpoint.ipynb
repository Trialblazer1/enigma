# %%
### Please run this cell to see the code breaking of code 2 ###
### The missing starting positions setting that was used to break the code is provided below in the code ###
### To run the code manually head to the below cell and follow the corresponding instructions ###

import itertools
from itertools import permutations
from itertools import combinations

from full_machine_pluglead import Pluglead
from full_machine_plugboard import PlugBoard
from full_machine_rotor import Rotor
from full_machine_reflector import Reflector
from full_machine_enigma import Enigma

#historical rotors and reflectors
# I = Rotor("EKMFLGDQVZNTOWYHXUSPAIBRCJ", "Q")
# II = Rotor("AJDKSIRUXBLHWTMCQGZNPYFVOE", "E")
# III = Rotor("BDFHJLCPRTXVZNYEIWGAKMUSQO", "V")
# IV = Rotor("ESOVPZJAYQUIRHXLNFTGKDCMWB", "J")
# V = Rotor("VZBRGITYUPSDNHLXAWMJQOFECK", "Z")
# Beta = Rotor("LEYJVCNIXWPBQMDRTAKZGFUHOS", None)
# Gamma = Rotor("FSOKANUERHMBTIYCWLQPZXVGJD", None)
# A = Reflector("EJMZALYXVBWFCRQUONTSPIKHGD")
# B = Reflector("YRUHQSLDPXNGOKMIEBFZCWVJAT")
# C = Reflector("FVPJIAOYEDRZXWGCTKUQSBNMHL")
### Please do not modify the above rotors and reflectors ###

def Code2(char):
    #rotors
    I = Rotor("EKMFLGDQVZNTOWYHXUSPAIBRCJ", "Q")
    III = Rotor("BDFHJLCPRTXVZNYEIWGAKMUSQO", "V")
    Beta = Rotor("LEYJVCNIXWPBQMDRTAKZGFUHOS", None)
    
    #reflector
    #A = Reflector("EJMZALYXVBWFCRQUONTSPIKHGD")
    B = Reflector("YRUHQSLDPXNGOKMIEBFZCWVJAT")
    #C = Reflector("FVPJIAOYEDRZXWGCTKUQSBNMHL")
    
    #plugboard
    pb = PlugBoard()
    pairs = ['VH', 'PT', 'ZG', 'BJ', 'EY', 'FS']
    pb.add(pairs)

    #Enigma machine
    rotors = (Beta,I,III)
    ref = B
    rings = (23,2,10)

    enigma = Enigma(ref,rotors,pb)
    enigma.ring_settings(rings)
    #enigma.starting_positions(key)
    
    def decrypt(message):
        encoded_message = ''
        for alpha in message:
            encoded_message = encoded_message + enigma.cipher(alpha)
        return encoded_message
    
    label = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    key_permut = list(permutations(label, 3))
    output = []
    
    for num in key_permut:
        key = num
        enigma.starting_positions(key)
        janad = decrypt(char)
        key = num
        if 'UNIVERSITY' in janad:
            output.append((janad, key))
    return output

Code2("CMFSUPKNCBMUYEQVVDYKLRQZTPUFHSWWAKTUGXMPAMYAFITXIJKMH")
# Out:
# [('IHOPEYOUAREENJOYINGTHEUNIVERSITYOFBATHEXPERIENCESOFAR', ('F', 'V', 'D'))]

# %%
"""
To manually run the code breaking code 2, make the necessary modifications to the starting positions (key), 
please uncomment the last line and then run the manual_code_break_2(char) function.
"""

import itertools
from itertools import permutations
from itertools import combinations

from full_machine_pluglead import Pluglead
from full_machine_plugboard import PlugBoard
from full_machine_rotor import Rotor
from full_machine_reflector import Reflector
from full_machine_enigma import Enigma

def manual_code_break_2(char):
    # I = Rotor("EKMFLGDQVZNTOWYHXUSPAIBRCJ", "Q")
    # II = Rotor("AJDKSIRUXBLHWTMCQGZNPYFVOE", "E")
    # III = Rotor("BDFHJLCPRTXVZNYEIWGAKMUSQO", "V")
    # IV = Rotor("ESOVPZJAYQUIRHXLNFTGKDCMWB", "J")
    # V = Rotor("VZBRGITYUPSDNHLXAWMJQOFECK", "Z")
    # Beta = Rotor("LEYJVCNIXWPBQMDRTAKZGFUHOS", None)
    # Gamma = Rotor("FSOKANUERHMBTIYCWLQPZXVGJD", None)
    
    #rotors
    Beta = Rotor("LEYJVCNIXWPBQMDRTAKZGFUHOS", None)
    I = Rotor("EKMFLGDQVZNTOWYHXUSPAIBRCJ", "Q")
    III = Rotor("BDFHJLCPRTXVZNYEIWGAKMUSQO", "V")
    
    #reflector
    #A = Reflector("EJMZALYXVBWFCRQUONTSPIKHGD")
    B = Reflector("YRUHQSLDPXNGOKMIEBFZCWVJAT")
    #C = Reflector("FVPJIAOYEDRZXWGCTKUQSBNMHL")
    
    #plugboard
    pb = PlugBoard()
    pairs = ['VH', 'PT', 'ZG', 'BJ', 'EY', 'FS']
    pb.add(pairs)

    #Enigma machine
    rotors = (Beta, I, III)
    ref = B
    rings = (23,2,10)
    key = ('FVD')

    enigma = Enigma(ref,rotors,pb)
    enigma.ring_settings(rings)
    enigma.starting_positions(key)

    message = char
    encoded_message = ''
    for alpha in message:
        encoded_message = encoded_message + enigma.cipher(alpha)
    return encoded_message

#manual_code_break_2("CMFSUPKNCBMUYEQVVDYKLRQZTPUFHSWWAKTUGXMPAMYAFITXIJKMH")
