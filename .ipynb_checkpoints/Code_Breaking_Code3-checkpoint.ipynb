# %%
### Please run this cell to see the code breaking of code 3 ###
### The missing settings of rotors, rings, and the reflector that were used to break the code is provided below in the code ###
### To run the code manually head to the below cell and follow the corresponding instructions ###

import itertools
from itertools import permutations
from itertools import combinations

from full_machine_pluglead import Pluglead
from full_machine_plugboard import PlugBoard
from full_machine_rotor import Rotor
from full_machine_reflector import Reflector
from full_machine_enigma import Enigma

#historical rotors and reflectors
# I = Rotor("EKMFLGDQVZNTOWYHXUSPAIBRCJ", "Q")
# II = Rotor("AJDKSIRUXBLHWTMCQGZNPYFVOE", "E")
# III = Rotor("BDFHJLCPRTXVZNYEIWGAKMUSQO", "V")
# IV = Rotor("ESOVPZJAYQUIRHXLNFTGKDCMWB", "J")
# V = Rotor("VZBRGITYUPSDNHLXAWMJQOFECK", "Z")
# Beta = Rotor("LEYJVCNIXWPBQMDRTAKZGFUHOS", None)
# Gamma = Rotor("FSOKANUERHMBTIYCWLQPZXVGJD", None)
# A = Reflector("EJMZALYXVBWFCRQUONTSPIKHGD")
# B = Reflector("YRUHQSLDPXNGOKMIEBFZCWVJAT")
# C = Reflector("FVPJIAOYEDRZXWGCTKUQSBNMHL")
### Please do not modify the above rotors and reflectors ###

def Code3(char):
    #rotors
    II = Rotor("AJDKSIRUXBLHWTMCQGZNPYFVOE", "E")
    IV = Rotor("ESOVPZJAYQUIRHXLNFTGKDCMWB", "J")
    Gamma = Rotor("FSOKANUERHMBTIYCWLQPZXVGJD", None)
    
    #reflector
    #A = Reflector("EJMZALYXVBWFCRQUONTSPIKHGD")
    #B = Reflector("YRUHQSLDPXNGOKMIEBFZCWVJAT")
    C = Reflector("FVPJIAOYEDRZXWGCTKUQSBNMHL")
    
    #plugboard
    pb = PlugBoard()
    pairs = ['FH', 'TS', 'BE', 'UQ', 'KD', 'AL']
    pb.add(pairs)

    #Enigma machine
    rotor = [II,IV,Gamma]
    rotors = list(permutations(rotor, 3))
    ring = [2,4,6,8,20,22,24,26]
    rings = list(permutations(ring, 3))
    ref = C
    key = 'EMY'
    
    def decrypt(message):
        encoded_message = ''
        for alpha in message:
            encoded_message = encoded_message + enigma.cipher(alpha)
        return encoded_message
    
    output = ''
    settings = []
    for i in rings:
        for j in rotors:
            enigma = Enigma(ref, j, pb)
            enigma.starting_positions(key)
            enigma.ring_settings(i)
            janad = decrypt(char)
            #print(janad)
            if 'THOUSANDS' in janad:
                output += janad
                settings.append(i)
    return output, settings

Code3("ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY")
# Out:
# ('PONFHYQLFPVANTTHOUSANDSOFNEWTREESEPCYYEARBYMERELYFORGETTINGWVDQETHEYPUTTHEIRACORNS',
#  [(24, 2, 8)])

# %%
"""
To manually run the code breaking code 3, make the necessary modifications to the rings, reflector(if necessary) 
and rotors(if necessary), please uncomment the below last line and then run the manual_code_break_3(char) function.
"""

import itertools
from itertools import permutations
from itertools import combinations

from full_machine_pluglead import Pluglead
from full_machine_plugboard import PlugBoard
from full_machine_rotor import Rotor
from full_machine_reflector import Reflector
from full_machine_enigma import Enigma

def manual_code_break_3(char):
    # I = Rotor("EKMFLGDQVZNTOWYHXUSPAIBRCJ", "Q")
    # II = Rotor("AJDKSIRUXBLHWTMCQGZNPYFVOE", "E")
    # III = Rotor("BDFHJLCPRTXVZNYEIWGAKMUSQO", "V")
    # IV = Rotor("ESOVPZJAYQUIRHXLNFTGKDCMWB", "J")
    # V = Rotor("VZBRGITYUPSDNHLXAWMJQOFECK", "Z")
    # Beta = Rotor("LEYJVCNIXWPBQMDRTAKZGFUHOS", None)
    # Gamma = Rotor("FSOKANUERHMBTIYCWLQPZXVGJD", None)
    
    #rotors
    II = Rotor("AJDKSIRUXBLHWTMCQGZNPYFVOE", "E")
    IV = Rotor("ESOVPZJAYQUIRHXLNFTGKDCMWB", "J")
    Gamma = Rotor("FSOKANUERHMBTIYCWLQPZXVGJD", None)
    
    #reflector
    #A = Reflector("EJMZALYXVBWFCRQUONTSPIKHGD")
    #B = Reflector("YRUHQSLDPXNGOKMIEBFZCWVJAT")
    C = Reflector("FVPJIAOYEDRZXWGCTKUQSBNMHL")
    
    #plugboard
    pb = PlugBoard()
    pairs = ['FH', 'TS', 'BE', 'UQ', 'KD', 'AL']
    pb.add(pairs)

    #Enigma machine
    rotors = (II,IV,Gamma)
    ref = C
    rings = (2,4,6,8,20,22,24,26) #choose three form among the list of even number rings
    key = ('EMY')

    enigma = Enigma(ref,rotors,pb)
    enigma.ring_settings(rings)
    enigma.starting_positions(key)

    message = char
    encoded_message = ''
    for alpha in message:
        encoded_message = encoded_message + enigma.cipher(alpha)
    return encoded_message

#manual_code_break_3("ABSKJAKKMRITTNYURBJFWQGRSGNNYJSDRYLAPQWIAGKJYEPCTAGDCTHLCDRZRFZHKNRSDLNPFPEBVESHPY")
